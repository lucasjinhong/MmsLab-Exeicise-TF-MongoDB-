# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import numpy as np

x = np.array([[147, 150, 153, 158, 163, 165, 168, 170, 173, 175, 178, 180, 183]]).T
y = np.array([[49, 50, 51, 54, 58, 59, 60, 62, 63, 64, 66, 67, 68]]).T

# %%
plt.plot(x, y, 'bo')
plt.ylabel('Weight (kg)')
plt.xlabel('Height (cm)')
# Out:
# Text(0.5, 0, 'Height (cm)')

# %%
print("Model slope:    ", model.coef_)
print("Model intercept:", model.intercept_)


weight = model.coef_ * height + model.intercept_
height = 166
print('The weight of person has height',height,'cm:',weight,'Kg')
# Out:
# Model slope:     [[0.55920496]]
# Model intercept: [-33.73541021]
# The weight of person has height 166 cm: [[59.09261348]] Kg
